# %% [markdown]
# # Python Basic

# %% [markdown]
# 1. What is python, and why is it popular?
#
#   -> Python is high level, interpreted, and general-purpose programming language. It is popular because of its simple syntax, readability, large community support, and vast collection of libraries for data science, web development, automation and AI.
#
# 2. What is an interpreter in pyhton?
#
#   -> An interpreter executes Pthyon code line by line, converting it into machine code at runtime. This make debugging simple but can be slower compared to compiled languages.
#
# 3. What are pre-defined keywords in Python?
#
#   -> keywords are reserved words in Python that have special meanings, and cannot be used as variable names. Examples: if , else, while, for, true, false, none.
#
# 4. Can keywords be used as variable names?
#
#  -> No. keywords are reserved and cannot be used as variable names.
#     EXAMPLE:

# %%
if = 20
#
# Out:
#   File "/tmp/ipython-input-2602365234.py", line 1
#     if = 20
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
#  5. What is mutability in Python?
#
#  -> Mutability means whether an object can be changed after creation. Mutable objectts can be modified( list, dictionaries), imumutable are objects cannot( tuples, strings).
#
#  6. Why are lists mutable, but tuples are immutable?
#
#   -> list are mutable so elements can be added, removed, or modified.
#
#   -> tuples are immutable to ensure data integrity and allow them to be used as dictonary keys or set elements.
#
#   7. What is the difference between "==" and "is" operators in Python?
#    -> == ->checks if values are equal.
#
#    .is -> checks if two objects refer to the same memory location.
#
#    8. What are logical operators is Python?
#
#    -> logical operators are used to combie conditional statements:
#    .and -> true if both conditons are true
#
#    .not -> negates the result
#
#    .or -> true if at least one conditon is true
#
#    9. What is type casting in Python?
#
#
# *   List item
# *   List item
#
#
#    -> Type casting is converting one data type into another.
#    Example:

# %%
x = "10"
y = int(x)   #Converts string to integer

# %% [markdown]
# 10. What is the difference between implicit and explicit type casting?
#
# -> Implicit(type conversion) - Python automatically converts one type to another. ex- 3 + 4.5 = 7.5
#  .Explicit(type casting) - programmer explicitly converts type using functions like int(), floot(), str().
#
# 11. What is the purpose of conditional statements in Python?
#
#  -> They allow decision-making in programs by executing different code blocks based on condition. ex- if, elif, else.
#
#  12. How does the elif statement work?
#
#  -> it allows multiple conditions to be checked one after another. Once a conditio is true, the corresponding block executes, and the rest are skipped.
#
#  13. What is the difference between for and while loops?
#
#   -> for loop - used when the number of iteration is known (iterates over sequencs).
#   . while loop - used when the number of iterations is unknown and depends on a conditon.
#
#   14. Describe a scenario where a while loop is more suitable than a for loop.
#
#   -> When you don't know how many times you need to repeat. ex- keep asking the user for input until they enter a valid number.

# %% [markdown]
# # Practical QUESTION

# %% [markdown]
# 1. Write a Python program to print ' Hello, world!'

# %%
print("hello, world")
# Out:
# hello, world

# %% [markdown]
# 2. Write a Python program that displays your name and age.

# %%
name = "gaurav"
age = 25
print("Name:", name)
print("Age:", age)
# Out:
# Name: gaurav
# Age: 25

# %% [markdown]
# 3. Write code to print all the pre- defined keywords in python using the keyword library.

# %%
import keyword
print(keyword.kwlist)
#
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# 4. Write a program that checks if a given word is a python keyword.

# %%
import keyword
word = "if"
if keyword.iskeyword(word):
    print(f"{word} is a python keyword.")
else:
    print(f"{word} is not a python keyword.")
# Out:
# if is a python keyword.

# %% [markdown]
# 5. Create a list and tuple in python, and demonstrate how attempting to change an element works differently for each.

# %%
my_list = [1, 2, 3]
my_tuple = (1, 2, 3)
my_list[0] = 10
print("Modified List:", my_list)

# my_tuple[0] = 10 #
print("Tuple is immutable:", my_tuple)
# Out:
# Modified List: [10, 2, 3]
# Tuple is immutable: (1, 2, 3)

# %% [markdown]
# 6. Write a function to demonstrate the behaviour of mutable and imuutable arguments.

# %%
def modify_list(my_list):
    my_list.append(4)
def modify_number(number):
    number += 10

my_list = [1, 2, 3]
modify_list(my_list)
print("List after modification:", my_list)

number = 5
modify_number(number)
print("Number after modification:", number)
#
#
# Out:
# List after modification: [1, 2, 3, 4]
# Number after modification: 5

# %% [markdown]
# 7. Write a program that performs basic arithmetic operations on two user-input numbers.

# %%
a = int(input("enter first number:"))
b = int(input("enter second number:"))

print("sum:", a+b)
print("difference:", a-b)
print("product:", a*b)
print("quotient:", a/b)
#

# %% [markdown]
# 8. Write a program to demonstrate the use of logical operators.

# %%
x, y = True, False
print(x and y)  # False
print(x or y)   # True
print(not x)    # False

# %% [markdown]
# 9. Write a python program to convert user input from string to integer, float, and booolen types.

# %%
value = input("Enter a number:, ")

print("Interger:", int(value))
print("Float:", float(value))
print("Boolean:", bool(value))

# %% [markdown]
# 10. Write codes to demonstrate type casting and list elements.

# %%
numbers = ["1", "2", "3"]
numbers = list (map(int, numbers))
print(numbers) # [1, 2, 3]

# %% [markdown]
# 11. Write a program that checks if a number is positive , negative, or Zero.

# %%
num = float(input("Enter a number: "))
if num > 0:
  print("The number is positive.")
elif num < 0:
  print("The number is negative.")
else:
  print("The number is zero.")

# %% [markdown]
# 12. Write a for loop to print numbers from 1 to 10.

# %%
for i in range(1, 11):
  print(i)

# %% [markdown]
# 13. Write a python program to find the sum of all even numbers between 1 and 50.

# %%
sum_even = sum(i for i in range(2, 51, 2))
print("Sum of even numbers between 1 and 50:", sum_even

# %% [markdown]
# 14. Write a program to reverse a string using a while loop.

# %%
text = input("Enter a string: ")
reversed_text = ""
index = len(text) - 1

while index >= 0:
  reversed_text += text[index]
  index -= 1

print("Reversed string:", reversed_text

# %% [markdown]
# 15. Write a python program to calculate the factorial of a number provided by the user using a while loop.

# %%
num = int(input("Enter a number: "))
factorial = 1
current = 1

while current <= num:
  factorial *= current
  current += 1

print(f"The factorial of {num} is {factorial}"
